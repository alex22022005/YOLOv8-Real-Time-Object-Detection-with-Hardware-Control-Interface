# %%
# Step 1: Install required libraries
# !pip install roboflow ultralytics

# Step 2: Import necessary modules
from roboflow import Roboflow
import os

# Step 3: Download dataset from Roboflow
rf = Roboflow(api_key="GUeccORHJBVBaiFUIxSy")
project = rf.workspace("ph-ambulance-dataset-with-augmentations").project("ph-ambulances")
version = project.version(1)
dataset = version.download("yolov8")

# Step 4: Train the YOLOv8 model
from ultralytics import YOLO

# Load YOLOv8n (or s/m/l/x based on preference)
model = YOLO('yolov8s.yaml')  # you can use yolov8s.yaml or yolov8n.yaml

# Train the model (this will create runs/detect/train/weights/best.pt)
results = model.train(data=os.path.join(dataset.location, "data.yaml"), epochs=20, imgsz=640)

# Step 5: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Step 6: Copy the best.pt file to Drive
# !cp runs/detect/train/weights/best.pt /content/drive/MyDrive/best.pt

# Optional: also keep a local copy
# !cp runs/detect/train/weights/best.pt ./best.pt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/211.5 MB 132.7 MB/s eta 0:00:02
# ERROR: Operation cancelled by user
# ...
